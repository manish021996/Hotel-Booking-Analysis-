# %% [markdown]
# <a href="https://colab.research.google.com/github/manish021996/Hotel-Booking-Analysis-python/blob/main/Hotel_Booking_Analysis_Team.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    -  **EDA**
# ##### **Contribution**    -  **Team**
# ##### **Team Member 1 - Manish H Magarde**
# ##### **Team Member 2 -Omkar B Adling**
# ##### **Team Member 3 - Rimoh R Sharma**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this project, We have attempted to analyze a hotel booking dataset and come up with some relevant conclusions which will help the hotel to improve performance. We had perform our analysis in 4 segments
# *   Booking Wise Analysis
# *   Customer Wise Analysis
# *   Cancellation wise Analysis
# *   RevenueWiseAnalysis
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# A dataset containing 119390 records across 32 features has been given with information regarding bookings of two hotels from July 2015 to August 2017.
# We explore and analyze the data to discover important factors that govern the bookings by
# * Understanding the business task.
# * Import relevant libraries and define useful functions.
# * Reading data from files given.
# * Data inspection.
# * Data cleaning.
# * Exploratory data analysis, to find which factors affect the bookings and how they affect it.
# * Conclusions drawn from analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/manish021996/Hotel-Booking-Analysis-python

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### **Hotel Booking Analysis**
# Analysing the hotel booking pattern is extremely important for the business as it help to recognizes type of customers, need of customers, peak duration of booking hotel, so that the executives of the hotels could make and ammend their policies accordingly.
# In this highly competitive market, making and maintaining a regular costumers is the biggest challenge for hotel industry.
# For that we are explore and analyze the data to discover important factors that govern the bookings of hotels.
# Data analysis is performed to answer the following questions:
#
#
# *   What are the booking percentage in each hotel ?
# *   Which are the top 10 countries in a Hotel Booking ?
# *   What are the booking percent of different distribution channels and market segments ?
# *   Which type of deposite is used most during booking in different hotel?
# *   What is trend of arrival of costumer in each hotel across every year and months ?
# *    Which hotel has highest rate of repeating guest ?
# *   What are the percentage of customers getting same roomtype as demand during booking ?
# *   what is avg car parking space req for each type of customers and which type of customer need more car parking space ?
# *    which meal is most prefered by customer in each hotel ?
# *   What are the cancellation and non cancellation rate among the different customer type ?
# *  Do longer lead time causes the cancellation of bookings ?
# *   Is there any chance of cancellation of booking if same room type is not alloted ?
# *   Do longer waiting timing put any impact in cancellation of booking ?
# *   What is the highest, lowest and avg adr for each distribution channel in each hotel ?
# *   Is increase in a special request help hotel to generate more revenue ?
# *   What is average adr per month in each hotel?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ### To attract the customer and increase the number of booking in hotels.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
hotel_df = pd.read_csv('/content/drive/MyDrive/AlmaBetter/Capstone Project/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look (First 5 and last 5 rows)
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(hotel_df[hotel_df.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(hotel_df.isnull().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(16,7))
sns.heatmap(hotel_df.isnull())
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1. This Datasets belongs to the Hotel industry and we have to analysis the booking, cancellation, stay and different segments of the hotels and insight behind it.
# 1. Datasets have have total 119390 columns and 32 rows.
# 2. over 16 columns have int datatype, 12 columns have object datatype and 4    columns have float datatype.
# 3. Some columns need to change their datatype like 'children', 'agent',   'company'  to int datatype and 'reservation_status_date' to datetime datatype.
# 4. some columns have missing value/null values which need to be handle .
# 5. Their are over 31994 duplicate rows in dataset which need to be deleted.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe (int datatype columns)
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# for object datatype columns 
hotel_df.describe(include='O')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# #### **The variables and the data it represents are listed below:**
#
# 1. **hotel** : Name of the hotel (Resort Hotel or City Hotel)
#
# 2. **is_canceled :** If the booking was canceled (1) or not (0)
#
# 3. **lead_time** : Number of days before the actual arrival of the guests
#
# 4. **arrival_date_year** : Year of arrival date
#
# 5. **arrival_date_month:** Month of arrival date
#
# 6. **arrival_date_week_number :** Week number of year for arrival date
#
# 7. **arrival_date_day_of_month :** Day of arrival date
#
# 8. **stays_in_weekend_nights :** Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
#
# 9. **stays_in_week_nights :** Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
# 10. **adults :** Number of adults among guests
#
# 11. **children :** Number of children among guests
#
# 12. **babies :** Number of babies among guests
#
# 13. **meal :** Type of meals
#
# 14. **country :** Country of guests (in code)
#
# 15. **market_segment :** which segments does customer belongs to.
#
# 16. **distribution_channel :** Name of booking distribution channel through which customers made booking.
#
# 17. **is_repeated_guest :** If the booking was from a repeated guest (1) or not (0)
#
# 18. **previous_cancellations :** Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19. **previous_bookings_not_canceled :** Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20. **reserved_room_type :** Code of room type reserved
#
# 21. **assigned_room_type :** Code of room type assigned
#
# 22. **booking_changes :** Number of changes/amendments made to the booking
#
# 23. **deposit_type :** Type of the deposit made by the guest
#
# 24. **agent :** ID of travel agent who made the booking
#
# 25. **company :** ID of the company that made the booking
#
# 26. **days_in_waiting_list :** Number of days the booking was in the waiting list
#
# 27. **customer_type :** Type of customer, assuming one of four categories
#
# 28. **adr :** Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29. **required_car_parking_spaces :** Number of car parking spaces required by the customer
#
# 30. **total_of_special_requests :** Number of special requests made by the customer
#
# 31. **reservation_status :** Reservation status (Canceled, Check-Out or No-Show)
#
# 32. **reservation_status_date :** Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in hotel_df.columns.tolist():
  print(f"No. of unique values in {i} is: {hotel_df[i].nunique()}")
# Out:
# No. of unique values in hotel is: 2
# No. of unique values in is_canceled is: 2
# No. of unique values in lead_time is: 479
# No. of unique values in arrival_date_year is: 3
# No. of unique values in arrival_date_month is: 12
# No. of unique values in arrival_date_week_number is: 53
# No. of unique values in arrival_date_day_of_month is: 31
# No. of unique values in stays_in_weekend_nights is: 17
# No. of unique values in stays_in_week_nights is: 35
# No. of unique values in adults is: 14
# No. of unique values in children is: 5
# No. of unique values in babies is: 5
# No. of unique values in meal is: 5
# No. of unique values in country is: 177
# No. of unique values in market_segment is: 8
# No. of unique values in distribution_channel is: 5
# No. of unique values in is_repeated_guest is: 2
# No. of unique values in previous_cancellations is: 15
# No. of unique values in previous_bookings_not_canceled is: 73
# No. of unique values in reserved_room_type is: 10
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### **Creating a copy of dataset hotel_df as df**

# %%
df = hotel_df.copy()
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### **Handling Null/Missing Values**

# %%
# tell the number of null values in each columns
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# filling null values as 0 
df[['agent','company']] = df[['agent','company']].fillna(0)

# %%
# filling null value as other
df['country'] = df['country'].fillna('other')

# %%
# filling all the null value as mean of children column
df['children'] = df['children'].fillna(df['children'].mean())

# %%
# checking null values after treating it 
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# ### **Converting columns datatype to appropriate datatype**

# %%
# converting into int datatype 
df[['children','agent','company']] = df[['children','agent','company']].astype('int')

# %%
# converting into datetime datatype
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %% [markdown]
# ### **Removing duplicate rows**

# %%
# checking for duplicate rows
df[df.duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
# deleting all duplicate rows
df.drop_duplicates(inplace = True)

# %%
# after deleting duplicate row the count of rows and columns
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ### **Adding new columns**

# %%
# creating a function which will cheak whether reserved_room_type is same as assigned_room_type or not 

def check_room_allot(x):
  if x['reserved_room_type'] == x['assigned_room_type']:
    return 'yes'
  else:
    return 'no'

# creating a column same_room_alloted by using lambda function
df['same_room_alloted'] = df.apply(lambda x : check_room_allot(x), axis = 1)

# %%
df['same_room_alloted']
# Out:
# 0         yes
# 1         yes
# 2          no
# 3         yes
# 4         yes
#          ...
# 119385    yes
# 119386    yes
# 119387    yes
# 119388    yes
# 119389    yes
# Name: same_room_alloted, Length: 87396, dtype: object

# %%
# creating a new column total_guest 
df['total_guests'] = df['adults'] + df['children'] + df['babies']

# %%
df['total_guests']
# Out:
# 0         2
# 1         2
# 2         1
# 3         1
# 4         2
#          ..
# 119385    2
# 119386    3
# 119387    2
# 119388    2
# 119389    2
# Name: total_guests, Length: 87396, dtype: int64

# %% [markdown]
# ### **Column Manipulations**

# %%
# replacing the values of is_canceled column from (0,1) to (not_canceled, canceled)
df['is_canceled'] = df.is_canceled.replace([1,0], ['canceled', 'not_canceled'])

# %% [markdown]
# ### **Creating some variables**

# %%
guest_country = df['country'].value_counts().reset_index().rename(columns={'index':'country','country':'no. of booking'})
guest_country
# Out:
#     country  no. of booking
# 0       PRT           27453
# 1       GBR           10433
# 2       FRA            8837
# 3       ESP            7252
# 4       DEU            5387
# ..      ...             ...
# 173     MMR               1
# 174     BFA               1
# 175     CYM               1
# 176     MLI               1
# 177     KHM               1
#
# [178 rows x 2 columns]

# %%
# Booking wise Top 10 country
booking_per_country = df['country'].value_counts()[:10].reset_index().rename(columns={'index':'country','country':'no of booking'})
booking_per_country
# Out:
#   country  no of booking
# 0     PRT          27453
# 1     GBR          10433
# 2     FRA           8837
# 3     ESP           7252
# 4     DEU           5387
# 5     ITA           3066
# 6     IRL           3016
# 7     BEL           2081
# 8     BRA           1995
# 9     NLD           1911

# %%
# To get count of each distribution channel 
distribution_channel = df.groupby(['distribution_channel'])
distribution_channel.size()
# Out:
# distribution_channel
# Corporate     5081
# Direct       12988
# GDS            181
# TA/TO        69141
# Undefined        5
# dtype: int64

# %%
# To get count of customer belong each market segements
market_segments = df.groupby('market_segment')
market_segments.size()
# Out:
# market_segment
# Aviation           227
# Complementary      702
# Corporate         4212
# Direct           11804
# Groups            4942
# Offline TA/TO    13889
# Online TA        51618
# Undefined            2
# dtype: int64

# %%
# to get count all deposit type used in city hotel bookings.
City_hotel_deposite = df[df['hotel'] == 'City Hotel'].groupby('deposit_type').size().reset_index(name='count')
City_hotel_deposite
# Out:
#   deposit_type  count
# 0   No Deposit  52568
# 1   Non Refund    845
# 2   Refundable     15

# %%
# to get counts all deposit type used in resort hotel booking.
Resort_hotel_deposite = df[df['hotel'] == 'Resort Hotel'].groupby('deposit_type').size().reset_index(name='count')
Resort_hotel_deposite
# Out:
#   deposit_type  count
# 0   No Deposit  33683
# 1   Non Refund    193
# 2   Refundable     92

# %%
# get the avg of repeting guest in each hotel.
avg_repeated_guest = (df.groupby(['hotel'])['is_repeated_guest'].mean()*100).reset_index().rename(columns = {'is_repeated_guest':'repeat guest %'})
avg_repeated_guest
# Out:
#           hotel  repeat guest %
# 0    City Hotel        3.196826
# 1  Resort Hotel        5.025318

# %%
# number of customers getting same room or not
same_room = df['same_room_alloted'].value_counts().reset_index(name = 'counts')
same_room
# Out:
#   index  counts
# 0   yes   74287
# 1    no   13109

# %%
# getting count of customers having same room or not for each room type
same_room_vs_room_types = df.groupby(['reserved_room_type','same_room_alloted']).size().reset_index(name = 'count')
same_room_vs_room_types
# Out:
#    reserved_room_type same_room_alloted  count
# 0                   A                no  10673
# 1                   A               yes  45879
# 2                   B                no    125
# 3                   B               yes    874
# 4                   C                no     48
# 5                   C               yes    867
# 6                   D                no   1414
# 7                   D               yes  15984
# 8                   E                no    587
# 9                   E               yes   5462
# 10                  F                no    187
# 11                  F               yes   2636
# 12                  G                no     53
# 13                  G               yes   1999
# 14                  H                no     17
# 15                  H               yes    579
# 16                  L                no      5
# 17                  L               yes      1
# 18                  P               yes      6

# %%
# avg car parking space requried for each customer type
avg_car_parking = (df.groupby(['customer_type'])['required_car_parking_spaces'].mean()*100).reset_index()
avg_car_parking
# Out:
#      customer_type  required_car_parking_spaces
# 0         Contract                     4.205161
# 1            Group                     9.375000
# 2        Transient                     8.873948
# 3  Transient-Party                     6.736591

# %%
# count of cancellation per customer type
cancelled = df[df['is_canceled'] == 'canceled'].groupby('customer_type').size().reset_index(name = 'count').rename(columns = {'count':'no. of cancellation'})
cancelled
# Out:
#      customer_type  no. of cancellation
# 0         Contract                  512
# 1            Group                   54
# 2        Transient                21672
# 3  Transient-Party                 1787

# %%
# count of non cancellation per customer type
not_cancelled = df[df['is_canceled'] == 'not_canceled'].groupby('customer_type').size().reset_index(name = 'count').rename(columns = {'count':'no. of non cancellation'})
not_cancelled
# Out:
#      customer_type  no. of non cancellation
# 0         Contract                     2627
# 1            Group                      490
# 2        Transient                    50314
# 3  Transient-Party                     9940

# %%
# count of cancel and not cancel for same room alloted 
is_cancell_vs_same_room = df.groupby(['same_room_alloted','is_canceled']).size().reset_index(name = 'count')
is_cancell_vs_same_room
# Out:
#   same_room_alloted   is_canceled  count
# 0                no      canceled    617
# 1                no  not_canceled  12492
# 2               yes      canceled  23408
# 3               yes  not_canceled  50879

# %%
# data have all the rows except where days_in_waiting_list = 0
waiting_days = df[df['days_in_waiting_list'] != 0]
waiting_days
# Out:
#                hotel   is_canceled  lead_time  arrival_date_year  \
# 2272    Resort Hotel  not_canceled         59               2015
# 2486    Resort Hotel  not_canceled         47               2015
# 2508    Resort Hotel  not_canceled         47               2015
# 3106    Resort Hotel  not_canceled        105               2015
# 3118    Resort Hotel  not_canceled        105               2015
# ...              ...           ...        ...                ...
# 111978    City Hotel  not_canceled        345               2017
# 112021    City Hotel  not_canceled         34               2017
# 112822    City Hotel  not_canceled        344               2017
# 114733    City Hotel  not_canceled        322               2017
# 115990    City Hotel  not_canceled         73               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2272              October                        41
# 2486              October                        43
# ...

# %%
# There is outlier in adr column which need to be delete.
df.drop(df[df['adr'] > 5000].index,inplace = True)

# %%
# get the data where all the row  = city hotel
city_hotel_adr=df[df['hotel'] == 'City Hotel']
city_hotel_adr
# Out:
#              hotel   is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel  not_canceled          6               2015
# 40061   City Hotel      canceled         88               2015
# 40062   City Hotel      canceled         65               2015
# 40063   City Hotel      canceled         92               2015
# 40064   City Hotel      canceled        100               2015
# ...            ...           ...        ...                ...
# 119385  City Hotel  not_canceled         23               2017
# 119386  City Hotel  not_canceled        102               2017
# 119387  City Hotel  not_canceled         34               2017
# 119388  City Hotel  not_canceled        109               2017
# 119389  City Hotel  not_canceled        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# ...

# %%
# all the row where hotel = resort hotel 
resort_hotel_adr = df[df['hotel'] == 'Resort Hotel']
resort_hotel_adr
# Out:
#               hotel   is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel  not_canceled        342               2015
# 1      Resort Hotel  not_canceled        737               2015
# 2      Resort Hotel  not_canceled          7               2015
# 3      Resort Hotel  not_canceled         13               2015
# 4      Resort Hotel  not_canceled         14               2015
# ...             ...           ...        ...                ...
# 40055  Resort Hotel  not_canceled        212               2017
# 40056  Resort Hotel  not_canceled        169               2017
# 40057  Resort Hotel  not_canceled        204               2017
# 40058  Resort Hotel  not_canceled        211               2017
# 40059  Resort Hotel  not_canceled        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
# group the special request column and avg adr
special_req_= df.groupby(['total_of_special_requests'])['adr'].mean().reset_index().rename(columns={'adr':'avg adr'})
special_req_
# Out:
#    total_of_special_requests     avg adr
# 0                          0   99.544878
# 1                          1  109.651497
# 2                          2  118.570312
# 3                          3  125.070790
# 4                          4  131.088687
# 5                          5  129.980000

# %%
# to get avg adr/month
avg_adr_per_month = df.groupby(['hotel','arrival_date_month'])['adr'].mean().reset_index().rename(columns={'adr':'avg adr'})
avg_adr_per_month
# Out:
#            hotel arrival_date_month     avg adr
# 0     City Hotel              April  117.156250
# 1     City Hotel             August  124.901601
# 2     City Hotel           December   92.717339
# 3     City Hotel           February   88.945304
# 4     City Hotel            January   85.092612
# 5     City Hotel               July  120.055385
# 6     City Hotel               June  123.836342
# 7     City Hotel              March   93.670639
# 8     City Hotel                May  127.851240
# 9     City Hotel           November   89.454120
# 10    City Hotel            October  107.304166
# 11    City Hotel          September  118.546566
# 12  Resort Hotel              April   79.283805
# 13  Resort Hotel             August  187.566659
# 14  Resort Hotel           December   65.409093
# 15  Resort Hotel           February   54.081107
# 16  Resort Hotel            January   49.131584
# 17  Resort Hotel               July  156.166914
# 18  Resort Hotel               June  112.340141
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Data is a precious so we will not do any kind of manipulation with original dataset thatswhy we had created a copy of datasets.
# 2. First we check and handle all the null values:-
# a) Columns 'agent', 'company' have the most number of missing values.
# b) column 'company' have a company code and column 'agent' have a agent code  which are in numerical values.
# c) So, replace all the missing value of columns 'agent', 'company' with zero.
# d) Column 'country' have string datatype which have near 488 null value which were replace by other.
# e) Column 'children' also have null value which was replace by mean of the column, as there are some values in children column as 0 which means there was some booking which have 0 no. of children with them.
# 3. Second we had convert some columns datatype to appropriate datatype:-
# a) column 'children' is in float datatype which have a count of children
# which cannot be in decimal so we convert it into int.
# b) column reservation_status_date is in object datatype which have the date of booking of hotel which should be in datetime datatype.
# 4. Check and delet duplicate rows:-
# a) There are 31994 duplicate rows which are deleted.
# b) Now datasets have 87396 rows and 32 columns
# 5. Checking outliers
# 6. Adding new column same_room_alloat which have values (yes, no) so that we analysis what are the chances of getting same room.
# 7. Creating some variable which will be use in data visualization part.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Booking Wise Analysis**

# %% [markdown]
# ### Q1. What are the booking percentage in each hotel ?

# %%
# ploting pie chart through matplotlib
plt.pie(df.groupby(['hotel']).size(), labels = ['City Hotel', 'Resort Hotel'], explode = [0.1,0], autopct = '%0.2f%%', textprops = {'fontsize':15}, startangle=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently.
# So, I used Pie chart and which helped me to get the percentage comparision of booking in each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Around 61% bookings are for City hotel and around 38% bookings are for Resort hotel.
# Number of bookings for City Hotel is 1.6 times more than that of Resort Hotel. City Hotel seems to be more preferred among travellers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It seems that a huge proportion of hotels was city hotel. May be resort hotel tend to be on the expensive side and most people will just stick with city hotel.

# %% [markdown]
# ### Q2. Which are the top 10 countries in a Hotel Booking ?

# %%
plt.figure(figsize = (14,12))

# ploting map through plotly
plt.subplot(2,1,1)
guest_map = px.choropleth(guest_country, locations=guest_country['country'], color=np.log(guest_country['no. of booking']), hover_name=guest_country['country'], color_continuous_scale=px.colors.sequential.Plasma,
                          title="Home country of guests")
guest_map.show()

# ploting bar chart through seaborn
plt.subplot(2,1,1)
sns.barplot(x = 'country', y = 'no. of booking', data = guest_country[:10]).set_title('Top 10 Country in Hotel Booking', fontsize = 15)
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable.
# Bar plot is used here because we need to find the trend of booking over a categorical columns country.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We have a huge number of visitors from western europe, Portugal being the highest followed by Great Britain and France.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it will definately create a impact we can say our maketing department to target audience geographically.

# %% [markdown]
# ### Q3. What are the booking percent of different distribution channels and market segments ?

# %%
plt.figure(figsize = (16,9))

# ploting pie chart through matplotlib
plt.subplot(1,2,1)
explode =[0,0,0,0.2,0]
name1 = ['Corporate','Direct','GDS','TA/TO','Undefined']
textsize = {'fontsize':13}

plt.pie(distribution_channel.size(), labels = name1, explode = explode, autopct = '%0.2f%%', textprops = textsize, colors = ['steelblue','r','b','c','m'])
plt.title('Distribution Channels',fontsize = 20)

plt.subplot(1,2,2)
explode =[0,0,0,0,0,0,0.1,0]
name2 = ['Aviation', 'Complementary', 'Corporate', 'Direct', 'Groups', 'Offline TA/TO', 'Online TA', 'Undefined']

plt.pie(market_segments.size(),autopct = '%0.2f%%',explode = explode, textprops = textsize, labels = name2, colors = ['m','steelblue','grey','y','b','lightgreen','pink','r'])
plt.title('Market Segments',fontsize = 20)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently.
#  So, I used Pie chart and which helped me to get the percentage comparision of using each distribution channel and market segment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the booking are made through TA/TO channel followed by Direct channel. In case of market segments, costumer belong to online TA has highest no.of booking followed by offline TA/TO

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can target our marketing area to be on these travel agencies website and work with them since majority of the visitors tend to reach out to them.

# %% [markdown]
# ### Q​4. Which type of deposite is used most during booking in different hotel?

# %%
plt.figure(figsize = (16,6))

# ploting bar chart through seaborn
plt.subplot(1,2,1)
sns.barplot(data = City_hotel_deposite, x = 'deposit_type', y = 'count').set_title('Deposit type in City Hotel',fontsize = 15)

plt.subplot(1,2,2)
sns.barplot(data = Resort_hotel_deposite, x = 'deposit_type', y = 'count').set_title('Deposit type in Resort Hotel',fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable.
# So, here I use bar plot to get the trend of each deposite type used during booking of hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majority of the booking does not require deposit in both city or resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Because majority of the booking does not require deposit.This could lead easy cancellation of booking.

# %% [markdown]
# ### **Customer Wise Analysis**

# %% [markdown]
# ### Q1. What is trend of arrival of costumer in each hotel across every year and months ?

# %%
plt.figure(figsize = (12,12))

# ploting count plot chartt through seaborn
plt.subplot(2,1,1)
sns.countplot(data = df[['arrival_date_year','hotel']], x = 'arrival_date_year',hue = 'hotel').set_title('Total no. of gusset arrived in each year', fontsize = 20)

plt.subplot(2,1,2)
sns.countplot(data = df[['arrival_date_month','hotel']], x = 'arrival_date_month',hue = 'hotel',order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
          'August', 'September', 'October', 'November', 'December']).set_title('Total no. of gusset arrived in each month', fontsize = 20)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot is used to show the counts of observations in each categorical bin using bars.
# We used count plot to get the count of the gusset arrived for each year and months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that 2016 seems to be the year where hotel booking is a its highest.                                                                        We also see an increasing trend in booking around the middle of the year, with August being the highest. It seem that from July to August is a peak time period of hotel booking.
# Every month city hotels are lending in hotel booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No. of booking in year 2015 is more in resort hotel compare to city hotel but in year 2016 and 2017 city hotel has more booking then resort hotel.
# People are perfering city hotel more as compare to resort hotel.
# We can also see their is a sudden rise in booking in year 2016 which was again drop in year 2017.

# %% [markdown]
# ### Q2. Which hotel has highest rate of repeating guest ?

# %%
# ploting bar chart through seaborn
sns.barplot(data = avg_repeated_guest, x = 'hotel', y = 'repeat guest %').set_title(' Percentage of Repeating Guest ')
avg_repeated_guest
# Out:
#           hotel  repeat guest %
# 0    City Hotel        3.196826
# 1  Resort Hotel        5.025318

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable.
# Sometimes, bar charts show other statistics, such as percentages.
# To Show avg %age of repeating guest with repect to each hotel we use bar plot here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Resort hotel has a highest percentage of repeating guest which is around 5% compare to city hotel which is around 3%.
# We can also see low number of repeated guests in both city hotel as well as resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A need to target repeated guests since they have booked before.
# City hotel need to focus more on repeating guest as it have more percentage of booking compare to resort hotel but still manage low percentage of repeating guest compare to resort hotel

# %% [markdown]
# ### Q3. What are the percentage of customers getting same roomtype as demand during booking ?

# %%
plt.figure(figsize = (14,5))

# ploting pie chart through matplotlib
plt.subplot(1,2,1)
plt.pie(same_room['counts'], labels = same_room['index'], autopct = '%0.2f%%', explode = [0.2,0], textprops = {'fontsize' : 15})
plt.title('Percentage of getting same room type', fontsize =13 )

# ploting bar chart through seaborn
plt.subplot(1,2,2)
sns.barplot(x = 'reserved_room_type', y = 'count', hue = 'same_room_alloted', data = same_room_vs_room_types, palette = 'Dark2') 

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here first we use pie chart which are used to represent the proportional data or relative data in a single chart. The concept of pie slices is used to show the percentage of a particular data from the whole pie.
# So, we want to show a percentage comparision for same room alloted or not we use pie chart.
# Then we use bar plot which is used when you want to show a distribution of data points or perform a comparison of metric values across different subgroups of your data. From a bar chart, we can see which groups are highest or most common, and how other groups compare against the others.
# Thus we use bar chart here to get the trend of alloting the same room over subgroup of  reserved room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Nearly 85% people gets same roomtype which they have demand during bookingtime but still there are 15% changes that people will not get same room.
# Here we can also see demand of room type A is highest followed by room D.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can tell the city hotel staff to upgrade the room of the customers which will make customer happy and also makes them more loyal to them.

# %% [markdown]
# ### Q4. what is avg car parking space req for each type of customers and which type of customer need more car parking space ?

# %%
# ploting bar chart through seaborn
plt.figure(figsize = (8,5))
sns.barplot(data = avg_car_parking , x = 'customer_type', y = 'required_car_parking_spaces',palette = 'hot') .set_title('Avg car parking space req for each customer type',fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable.
# Sometimes, bar charts show other statistics, such as percentages.
# We use bar plot here because we need to get the trend of the car parking space  over categorical column which is customer type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Group and transient customer required more parking spaces as compared to other.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As per graphs we can also analysis that majority of customers do not required car parking space as percentage of required car parking space is less.

# %% [markdown]
# ### Q5. which meal is most prefered by customer in each hotel ?

# %%
plt.figure(figsize = (14,6))

# ploting count plot chart through seaborn
plt.subplot(1,2,1)
sns.countplot(x = 'meal',  data = df).set_title('Most perfered meal',fontsize = 15)

plt.subplot(1,2,2)
sns.countplot(x = 'meal',hue = 'hotel', data = df).set_title('Most perfered meal in each hotel',fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot is used to Show the counts of observations in each categorical bin using bars.
# We use the count plot of here to get the count of each meal had by the customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most preferred meal is BB(Bread and Breakfast) in both type of hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As most prefered meal is bed and breakfast the hotel staff  has to prepared for that need.

# %% [markdown]
# ### **Cancellation Wise Analysis**

# %% [markdown]
# ### Q1. What are the cancellation and non cancellation rate among the different customer type ?

# %%
plt.figure(figsize = (16,5))

colors = ['r','b','c','g']

# ploting bar chart through seaborn
plt.subplot(1,2,1)
sns.barplot(data = cancelled, x = 'customer_type', y = 'no. of cancellation').set_title('Cancellation rate', fontsize = 15)

plt.subplot(1,2,2)
sns.barplot(data = not_cancelled, x = 'customer_type', y = 'no. of non cancellation').set_title('non Cancellation rate', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is used when you want to show a distribution of data points or perform a comparison of metric values across different subgroups of your data. From a bar chart, we can see which groups are highest or most common, and how other groups compare against the others.
# We use bar plot here because we need to find the trend of cancellation and non cancelation over categorical column which is customer_type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient customer tends to do more cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Almost one third of booking are cancelled, hotel staff can give the room of tranient customer to other if room are not available as they tends to cancel a lot.

# %% [markdown]
# ### Q2. Do longer lead time causes the cancellation of bookings ?

# %%
# ploting kde chart through seaborn
plt.figure(figsize = (8,6))
sns.kdeplot(df['lead_time'], hue = df['is_canceled']).set_title('Booking cancellation vs lead time', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# kde plot is a non-parametric way to estimate the probability density function (PDF) of a random variable.
# Here we use Kde plot because we need find the density of cancellation and non cancellation over a range of lead_time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Can be the reasone behind cancellation as more the lead time more amount of cancellation occurs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel staff has to reduce the lead time so that their will be less cancellation.

# %% [markdown]
# ### Q3. Is there any chance of cancellation of booking if same room type is not alloted ?

# %%
# ploting bar chart through seaborn
plt.figure(figsize = (8,6))
sns.barplot(x = 'same_room_alloted', y = 'count', data = is_cancell_vs_same_room, hue = 'is_canceled').set_title('Same room type vs Cancellation', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We use bar plot here because we need to find the trend of cancellation and non cancelation over categorical column which is same_room_alloted.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can clearly say that not assigned the same room is not a reason for cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not assigning same room is not a reason behind cancellation as most of the cancellation are from the people who got the same room. Need to see other factor for cancellations.

# %% [markdown]
# ### Q4.Do longer waiting timing put any impact in cancellation of booking ?

# %%
# ploting kde chart through seaborn
plt.figure(figsize =(8,6))
sns.kdeplot(waiting_days['days_in_waiting_list'],hue = waiting_days['is_canceled']).set_title('Waiting time vs Cancellation',fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# kde plot is a non-parametric way to estimate the probability density function (PDF) of a random variable.
# As we need find the density of cancellation and non cancellation over a range of waiting days

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Longer waiting time hardly matter in cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Though it hardly matter still some amount of customers tends to do cancellation with longer waiting period the hotel staff has to look in that matter.

# %% [markdown]
# ### **Revenue Wise Analysis**

# %% [markdown]
# ### Q1. What is the highest, lowest and avg adr for each distribution channel in each hotel ?

# %%
plt.figure(figsize = (14,6))

# ploting box plot through seaborn
plt.subplot(1,2,1)
sns.boxplot(x = city_hotel_adr['distribution_channel'], y= city_hotel_adr['adr']).set_title('City Hotel',fontsize = 15)

plt.subplot(1,2,2)
sns.boxplot(x = resort_hotel_adr['distribution_channel'], y= resort_hotel_adr['adr']).set_title('Resort Hotel',fontsize = 15)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups.
# Our requirement is to find max, min, avg adr and Box plot is used to get the displays the five-number summary of a set of data.The five-number summary is the minimum, first quartile, median, third quartile, and maximum.
# So, we can get all the 3 insight (highest, lowest and avg) in a signle chart i.e, we use box plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In both the hotels more revenue deals is generated through Direct distribution channel followed by TA/TO and less revenue deals through corporate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We had seen earlier that TA/TO is making more no. of booking then others but still not able to generate more revenue deal in both the hotels compare to direst channels.
# Resort Hotel need to increase outreach on GDS and corporate channel to increase revenue.

# %% [markdown]
# ### Q2. Is increase in a special request help hotel to generate more revenue ?

# %%
# ploting Implot through seaborn
plt.figure(figsize = (8,6))
sns.lmplot(x= 'total_of_special_requests', y = 'avg adr', data= special_req_)
plt.title('Relation b/w special request and adr',fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We use Implot here because we need to find the correlation between to columns i.e, adr and total_special_request.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Yes we can see that avg adr is increasing as the number of special request is increasing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can conclude that increase in special request helps the hotel to generate more revenue.

# %% [markdown]
# ### Q3. What is average adr per month in each hotel ?

# %%
# ploting line chart through seaborn
plt.figure(figsize = (12,6))
sns.lineplot(data = avg_adr_per_month, x = 'arrival_date_month', y = 'avg adr', hue = 'hotel').set_title('Avg adr per month',fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is used to show the change in information over time.
# As line chart is use to get the trend over time and as a demand is also here is to get the trend of avg adr over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The city hotel have higher adr in the month of may as compare to resort hotel which has higher in the month of august.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see from the chart that resort hotel tends to have more flucation in adr compared to city hotel. The fluctution is more in resort hotel rangining from as high as 180 to as low as 20. the city hotel much or less have comsistent adr in between 100-120.

# %% [markdown]
# ### **Correlation Heatmap**

# %%
# ploting correlationt heatmap through seaborn
correlation_heatmap = df[['lead_time', 'previous_cancellations', 'previous_bookings_not_canceled', 'total_guests',
                    'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']].corr()
plt.figure(figsize = (16,9))
sns.heatmap(correlation_heatmap, annot = True, annot_kws={'size': 15}, vmax=.8).set_title('Correlation Heatmap',fontsize = 25)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the correlation between all numerical columns.
# A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, i used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the heatmap, it shows some high correlations between few variables, thats because we have created some new columns from existing columns.
# total_guest and adr are higely positively correlated by 39% which means which conclude that increase in no. of guest also increase in adr.
# adr and total_of_special_request are also positively correlated by 14% which conclude that increase in special request also increase in adr.
# total_of_special_request and total_guest is also positively correlated by 13% which conclude total special requests depends more on total members arrived.
# Average daily revenue depends more on total special requests and total members as compared to other variables.

# %% [markdown]
# ### **Pair Plot**

# %%
# ploting pair plot through seaborn
plt.figure(figsize = (16,12))
pair_plot_data = df[['hotel','adr','total_of_special_requests','stays_in_week_nights','stays_in_weekend_nights']]
sns.pairplot(pair_plot_data, hue = 'hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
#
# Thus, I used pair plot to analyse the patterns of data and realationship between the features. It's exactly same as the correlation map but here you will get the graphical representation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * City hotel is generating more revenue then resort hotel.
# * City hotel has more number of special request compare to resort hotel.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# #### * Large Number of booking are through online source so the hotel has to focus more on digital advertisment and increse their presence on social media. Also tell customers to right reviews which will let other customer know about their hotel performance.
# #### * Offer discounts to the customers who had made a booking previously to increase the percentage of repeating customers.
# #### * Target our marketing area to be on travel agencies website and also target audience geographically.
# #### * Target different country or region as most of the people are from europe. To increse customer base outside europe more advertisement and more brand awarness require in that targeted regions like america or asia.
# #### * Set Non-refundable Rates, Collect deposits, and implement more rigid cancellation policies.
# #### * Monitor where the cancellations are coming from such as Lead time, Customer type, distribution channels, etc.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# #### 1.   City hotel has around 61% of booking and mostly preferred by the customers.
# #### 2.   Highest number of the guest is from Portugal.
# #### 3.   Most of the booking are made through Travel Agent and Travel Operators.
# #### 4.   Most of the booking do not required any deposite which may tends to high cancellation rate.
# #### 5.   Most number of bookings are made in the months of July and Augest.
# #### 6.   Resort hotel has more number of repeating guest compare to city hotel.
# #### 7.   85% customer getting same room as per demand.
# #### 8.   Room Type A is the most preferred room type among travellers
# #### 9.    Majority of the customer do not required car parking space.
# #### 10.    From meal we can observe that BB (Bread and Breakfast) is the most preferred meal amongs customers in both the hotels.
# #### 11.   Almost 33% of the total booking are cancelled and most numbers of booking where cancelled by transient customer.
# #### 12.   Number of days in waiting list and not assigning the same room to customer does not affect cancellation of bookings.
# #### 13.   More revenue deal is generated through Direct distribution channel.
# #### 14.   Increase in a special request help hotel to generate more revenue.
# #### 15.   In month of May city hotel has high booking price whereas in month of August resort hotel has high booking price.
# #### 16.   adr and total guest are positively correlated by 41% which conclude that increase in number of guest also increase in adr.
# #### 17. City hotel are generating more revenue and getting more number of special request compare to resort hotel.
# #### 18. People who stay for long duration prefer resort hotel most
